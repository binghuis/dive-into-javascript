// %%
// @ts-ignore
import * as acorn from "acorn";

const code = `const a = 1;console.log(a)`;

[...acorn.tokenizer(code, { ecmaVersion: 2015 })];
// Out:
// [
//   Ce {
//     type: v {
//       label: "const",
//       keyword: "const",
//       beforeExpr: false,
//       startsExpr: false,
//       isLoop: false,
//       isAssign: false,
//       prefix: false,
//       postfix: false,
//       binop: null,
//       updateContext: null
//     },
//     value: "const",
//     start: 0,
//     end: 5
//   },
//   Ce {
//     type: v {
//       label: "name",
//       keyword: undefined,
//       beforeExpr: false,
//       startsExpr: true,
//       isLoop: false,
//       isAssign: false,
//       prefix: false,
//       postfix: false,
//       binop: null,
//       updateContext: [Function (anonymous)]
//     },
//     value: "a",
//     start: 6,
//     end: 7
//   },
//   Ce {
//     type: v {
//       label: "=",
//       keyword: undefined,
//       beforeExpr: true,
//       startsExpr: false,
//       isLoop: false,
//       isAssign: true,
//       prefix: false,
//       postfix: false,
//       binop: null,
// ...
