// %% [markdown]
// # 词法分析产物 token
//
// token 是源代码的最小单位，是构成源代码的基本元素。
//
// 它们描述了代码的基本信息，比如代码的类型、值和位置等。

// %%
// @ts-ignore
import * as acorn from "acorn";

const tokens = [
  ...acorn.tokenizer(`const a = 1;console.log(a)`, { ecmaVersion: 2015 }),
];

console.log(JSON.stringify(tokens, null, 2));
// Out:
// [
//   {
//     "type": {
//       "label": "const",
//       "keyword": "const",
//       "beforeExpr": false,
//       "startsExpr": false,
//       "isLoop": false,
//       "isAssign": false,
//       "prefix": false,
//       "postfix": false,
//       "binop": null,
//       "updateContext": null
//     },
//     "value": "const",
//     "start": 0,
//     "end": 5
//   },
//   {
//     "type": {
//       "label": "name",
//       "beforeExpr": false,
//       "startsExpr": true,
//       "isLoop": false,
//       "isAssign": false,
//       "prefix": false,
//       "postfix": false,
//       "binop": null
//     },
//     "value": "a",
//     "start": 6,
//     "end": 7
//   },
//   {
//     "type": {
//       "label": "=",
//       "beforeExpr": true,
//       "startsExpr": false,
//       "isLoop": false,
//       "isAssign": true,
//       "prefix": false,
//       "postfix": false,
//       "binop": null,
//       "updateContext": null
//     },
//     "value": "=",
// ...
